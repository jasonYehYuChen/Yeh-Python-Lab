# %%
# %matplotlib inline
#from ipywidgets import interact
import matplotlib.pyplot as plt
import numpy as np
import requests
import json

# %%
def data_month(year=2018,month=6):
    a=str(year)
    b=str(month)
    url_TSMC = 'http://www.twse.com.tw/exchangeReport/STOCK_DAY?response=json&date='+a+b+'01&stockNo='+'2330'
    res = requests.get(url_TSMC)
    D = json.loads(res.text)
    CL_price=[]#Closing price
    for col in (D['data']):
        CL_price.append(col[6])
    s=plt.plot(CL_price);
    return s;

# %%
from ipywidgets import interact
interact(data_month,year ='Hi there',month ='Hi there')
# Out:
# interactive(children=(Text(value='Hi there', description='year'), Text(value='Hi there', description='month'),…
# <function __main__.data_month(year=2018, month=6)>

# %%
data_month(2011,3)
